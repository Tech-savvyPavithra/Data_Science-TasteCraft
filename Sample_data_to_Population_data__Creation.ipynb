# %% [markdown]
# <a href="https://colab.research.google.com/github/Tech-savvyPavithra/Data_Science-TasteCraft/blob/main/Sample_data_to_Population_data__Creation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Manually Created Sample Data with 50 Observations as Excel File after performing Feature Engineering

# %%
import pandas as pd
sample=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/My Workouts/Yummy.csv')
print(sample)
# Out:
#     Flavor Intensity  Texture Complexity  \
# 0                8.5                 4.2
# 1                7.2                 3.5
# 2                9.0                 4.8
# 3                6.8                 3.0
# 4                8.3                 4.5
# 5                7.5                 3.8
# 6                9.2                 5.0
# 7                6.5                 2.8
# 8                8.0                 4.0
# 9                7.0                 3.2
# 10               9.5                 5.0
# 11               6.2                 2.5
# 12               8.7                 4.7
# 13               7.8                 3.9
# 14               9.3                 4.9
# 15               6.0                 2.5
# 16               8.5                 4.3
# 17               7.3                 3.6
# 18               9.1                 4.8
# 19               6.7                 3.0
# 20               8.2                 4.2
# 21               7.6                 3.7
# ...

# %%
sample.columns
# Out:
# Index(['Flavor Intensity', 'Texture Complexity',
#        'Spice Profile[0:Mild 1:Medium 2:Balanced 3:Spicy]', 'Freshness Index',
#        'Culinary Technique Score',
#        'Aroma Richness[0:Low 1:High 2:Moderate 3:Very High]', 'Tastiness'],
#       dtype='object')

# %%
sample.shape
# Out:
# (50, 7)

# %%
sample.head()
# Out:
#    Flavor Intensity  Texture Complexity  \
# 0               8.5                 4.2
# 1               7.2                 3.5
# 2               9.0                 4.8
# 3               6.8                 3.0
# 4               8.3                 4.5
#
#    Spice Profile[0:Mild 1:Medium 2:Balanced 3:Spicy]  Freshness Index  \
# 0                                                  2              9.0
# 1                                                  1              8.2
# 2                                                  3              9.5
# 3                                                  1              7.5
# 4                                                  2              8.8
#
#    Culinary Technique Score  \
# 0                       7.8
# 1                       6.5
# 2                       8.5
# 3                       6.2
# 4                       7.0
#
#    Aroma Richness[0:Low 1:High 2:Moderate 3:Very High]  Tastiness
# ...

# %% [markdown]
# Transforming Sample Data into Population Data

# %%
import random
import pandas as pd

# %%
[w1,w2,w3,w4,w5,w6]=[-4.039,2.568,-0.209,1.374,1.654,-0.513]
vals=[]
for i in range(10000):
    x1=random.randint(6,10)
    x2=random.randint(1,5)
    x3=random.randint(0,3)
    x4=random.randint(6,10)
    x5=random.randint(6,10)
    x6=random.randint(0,3)
    eq=w1*x1+w2*x2+w3*x3+w4*x4+w5*x5+w6*x6
    vals.append([x1,x2,x3,x4,x5,x6,eq])
df=pd.DataFrame(vals,columns=['Flavor Intensity','Texture Complexity','Spice Profile[0:Mild 1:Medium 2:Balanced 3:Spicy]','Freshness Index','Culinary Technique Score','Aroma Richness[0:Low 1:High 2:Moderate 3:Very High]','Tastiness'])
df.to_csv('/content/drive/MyDrive/Colab Notebooks/My Workouts/New_Yummy.csv',index=False)

# %% [markdown]
# Population Data with 10,000 Observations

# %%
import pandas as pd
population=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/My Workouts/New_Yummy.csv')
print(population)
# Out:
#       Flavor Intensity  Texture Complexity  \
# 0                    7                   5
# 1                    7                   2
# 2                   10                   4
# 3                    9                   5
# 4                    9                   2
# ...                ...                 ...
# 9995                 8                   3
# 9996                 7                   1
# 9997                 8                   4
# 9998                 8                   4
# 9999                 8                   5
#
#       Spice Profile[0:Mild 1:Medium 2:Balanced 3:Spicy]  Freshness Index  \
# 0                                                     1                9
# 1                                                     1                7
# 2                                                     1                7
# 3                                                     2                6
# 4                                                     1                6
# ...

# %%
population.columns
# Out:
# Index(['Flavor Intensity', 'Texture Complexity',
#        'Spice Profile[0:Mild 1:Medium 2:Balanced 3:Spicy]', 'Freshness Index',
#        'Culinary Technique Score',
#        'Aroma Richness[0:Low 1:High 2:Moderate 3:Very High]', 'Tastiness'],
#       dtype='object')

# %%
population.shape
# Out:
# (10000, 7)

# %%
population.head()
# Out:
#    Flavor Intensity  Texture Complexity  \
# 0                 7                   5
# 1                 7                   2
# 2                10                   4
# 3                 9                   5
# 4                 9                   2
#
#    Spice Profile[0:Mild 1:Medium 2:Balanced 3:Spicy]  Freshness Index  \
# 0                                                  1                9
# 1                                                  1                7
# 2                                                  1                7
# 3                                                  2                6
# 4                                                  1                6
#
#    Culinary Technique Score  \
# 0                         9
# 1                         6
# 2                         7
# 3                        10
# 4                         7
#
#    Aroma Richness[0:Low 1:High 2:Moderate 3:Very High]  Tastiness
# ...
